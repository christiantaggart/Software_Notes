# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
from scipy.stats import bernoulli
from scipy.stats import binom
from scipy.stats import poisson
from scipy.stats import stats
# %matplotlib inline

# %%
distribution = norm(loc=0, scale=1)
xs = np.linspace(-3.0, 3.0, 100)
ys = distribution.pdf(xs)
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10, 5))
ax.plot(xs, ys)
ax.set_title('PDF norm(mu=0, sigma=1)', size=20)
ax.set_xlabel('x in standard deviations', size=15)
ax.set_ylabel('pdf(x)', size=15)

# %%
distribution = norm(loc=0, scale=1)
xs = np.linspace(-3.0, 3.0, 100)
ys = distribution.cdf(xs)
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10, 5))
ax.plot(xs, ys)
ax.set_title('CDF norm(mu=0, sigma=1)', size=20)
ax.set_xlabel('x in standard deviations', size=15)
ax.set_ylabel('cdf(x)', size=15)

# %%
data = np.array([1.0, 9.2, 10.6, 5.2, 15.1])
np.mean(data)
# Out:
# 8.2199999999999989

# %%
data = np.array([1.0, 9.2, 10.6, 5.2, 15.1])
np.median(data)
# Out:
# 9.1999999999999993

# %%
data = np.array([1, 2, 3, 4, 3, 3, 2])
stats.mode(data)
# data.mode()
# Out:
# ModeResult(mode=array([3]), count=array([3]))

# %%
data2 = [45,65,37,43,25,36,47,62]

# %%
np.mean(data2)
# Out:
# 45.0

# %%
np.median(data2)
# Out:
# 44.0

# %%
stats.mode(data2)
# Out:
# ModeResult(mode=array([25]), count=array([1]))

# %%
stats.iqr(data2)
# Out:
# 14.0

# %%
stats.q1(data2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-445ff03225d1> in <module>()
# ----> 1 stats.q1(data2)
#
# AttributeError: module 'scipy.stats.stats' has no attribute 'q1'

# %%
np.percentile(data2,25)
# Out:
# 36.75

# %%
np.percentile(data2,75)
# Out:
# 50.75

# %%
data3 = [45,65,37,43,25,36,47,62,103]

# %%
np.var(data3)
# Out:
# 470.24691358024694

# %%
# Input series of comma-separated strings
s = input('Please enter a series of comma-separated strings: ')
# Split on comma+space to create the list
l = s.split(', ')
# print(l)
l1 = l[1::2]
print(l1)

# Print the odd-indexed elements of list l
# Out:
# Please enter a series of comma-separated strings: zero, one, two, three, four, five, six
# ['one', 'three', 'five']

# %%
# Input series of comma-separated strings
s = input('Please enter a series of comma-separated strings: ')
# Split on comma+space to create the list
l = s.split(', ')
l.sort()
for num, item in enumerate(l):
    print(num + 1, item)

# Sort l, then print the elements of l in numbered fashion, starting at 1
# Out:
# Please enter a series of comma-separated strings: starfruit, cherry, banana, apple
# 1 apple
# 2 banana
# 3 cherry
# 4 starfruit
