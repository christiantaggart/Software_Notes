# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('./winequality-red.csv', delimiter=';')

# %%
df.head(n=7)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# ...

# %%
df.shape
# Out:
# (1599, 12)

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
# fixed acidity           1599 non-null float64
# volatile acidity        1599 non-null float64
# citric acid             1599 non-null float64
# residual sugar          1599 non-null float64
# chlorides               1599 non-null float64
# free sulfur dioxide     1599 non-null float64
# total sulfur dioxide    1599 non-null float64
# density                 1599 non-null float64
# pH                      1599 non-null float64
# sulphates               1599 non-null float64
# alcohol                 1599 non-null float64
# quality                 1599 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
# fixed acidity           1599 non-null float64
# volatile acidity        1599 non-null float64
# citric acid             1599 non-null float64
# residual sugar          1599 non-null float64
# chlorides               1599 non-null float64
# free sulfur dioxide     1599 non-null float64
# total sulfur dioxide    1599 non-null float64
# density                 1599 non-null float64
# pH                      1599 non-null float64
# sulphates               1599 non-null float64
# alcohol                 1599 non-null float64
# quality                 1599 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df['fixed acidity'] # returns a series
# Out:
# 0        7.4
# 1        7.8
# 2        7.8
# 3       11.2
# 4        7.4
# 5        7.4
# 6        7.9
# 7        7.3
# 8        7.8
# 9        7.5
# 10       6.7
# 11       7.5
# 12       5.6
# 13       7.8
# 14       8.9
# 15       8.9
# 16       8.5
# 17       8.1
# 18       7.4
# 19       7.9
# 20       8.9
# 21       7.6
# 22       7.9
# 23       8.5
# 24       6.9
# 25       6.3
# 26       7.6
# 27       7.9
# 28       7.1
# 29       7.8
#         ...
# 1569     6.2
# 1570     6.4
# 1571     6.4
# 1572     7.3
# 1573     6.0
# 1574     5.6
# 1575     7.5
# 1576     8.0
# 1577     6.2
# 1578     6.8
# 1579     6.2
# 1580     7.4
# 1581     6.2
# 1582     6.1
# 1583     6.2
# 1584     6.7
# 1585     7.2
# 1586     7.5
# 1587     5.8
# 1588     7.2
# 1589     6.6
# 1590     6.3
# 1591     5.4
# 1592     6.3
# 1593     6.8
# 1594     6.2
# 1595     5.9
# 1596     6.3
# 1597     5.9
# 1598     6.0
# Name: fixed acidity, Length: 1599, dtype: float64

# %%
df['fixed acidity'].head() #Grab just the first 5 of the series
# Out:
# 0     7.4
# 1     7.8
# 2     7.8
# 3    11.2
# 4     7.4
# Name: fixed acidity, dtype: float64

# %%
df[['fixed acidity', 'volatile acidity']].head() # a dataframe with two cols
# Out:
#    fixed acidity  volatile acidity
# 0            7.4              0.70
# 1            7.8              0.88
# 2            7.8              0.76
# 3           11.2              0.28
# 4            7.4              0.70

# %%
df[['fixed acidity']].head() # dataframe with just one column
# Out:
#    fixed acidity
# 0            7.4
# 1            7.8
# 2            7.8
# 3           11.2
# 4            7.4

# %%
df2 = df.copy() # create a copy of the dataframe

# %%
df2.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
cols = df2.columns.tolist()

# %%
cols
# Out:
# ['fixed acidity',
#  'volatile acidity',
#  'citric acid',
#  'residual sugar',
#  'chlorides',
#  'free sulfur dioxide',
#  'total sulfur dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol',
#  'quality']

# %%
cols2 = [col.lower().replace(' ', '_') for col in cols] # replace white space with underscores

# %%
cols2
# Out:
# ['fixed_acidity',
#  'volatile_acidity',
#  'citric_acid',
#  'residual_sugar',
#  'chlorides',
#  'free_sulfur_dioxide',
#  'total_sulfur_dioxide',
#  'density',
#  'ph',
#  'sulphates',
#  'alcohol',
#  'quality']

# %%
df2.colums = cols2

# %%
df2.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df3 = df.copy()

# %%
df3.rename(columns={'citric acid':'citric_acid'}, inplace = True) # another way to rename a columns

# %%
df3.head()
# Out:
#    fixed acidity  volatile acidity  citric_acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.loc[100:102] # Grab a range by index
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 100            8.3             0.610         0.30             2.1      0.084
# 101            7.8             0.500         0.30             1.9      0.075
# 102            8.1             0.545         0.18             1.9      0.080
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 100                 11.0                  50.0   0.9972  3.40       0.61
# 101                  8.0                  22.0   0.9959  3.31       0.56
# 102                 13.0                  35.0   0.9972  3.30       0.59
#
#      alcohol  quality
# 100     10.2        6
# 101     10.4        6
# 102      9.0        6

# %%
df.loc[100:102,'chlorides'] # selects just chlorides
# Out:
# 100    0.084
# 101    0.075
# 102    0.080
# Name: chlorides, dtype: float64

# %%
df.loc[100:102, ['chlorides','fixed acidity']] # selects chlorides and fixed acidity
# Out:
#      chlorides  fixed acidity
# 100      0.084            8.3
# 101      0.075            7.8
# 102      0.080            8.1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
# fixed acidity           1599 non-null float64
# volatile acidity        1599 non-null float64
# citric acid             1599 non-null float64
# residual sugar          1599 non-null float64
# chlorides               1599 non-null float64
# free sulfur dioxide     1599 non-null float64
# total sulfur dioxide    1599 non-null float64
# density                 1599 non-null float64
# pH                      1599 non-null float64
# sulphates               1599 non-null float64
# alcohol                 1599 non-null float64
# quality                 1599 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3])

# %%
df.groupby('quality').mean()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3             8.360000          0.884500     0.171000        2.635000
# 4             7.779245          0.693962     0.174151        2.694340
# 5             8.167254          0.577041     0.243686        2.528855
# 6             8.347179          0.497484     0.273824        2.477194
# 7             8.872362          0.403920     0.375176        2.720603
# 8             8.566667          0.423333     0.391111        2.577778
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# quality
# 3         0.122500            11.000000             24.900000  0.997464
# 4         0.090679            12.264151             36.245283  0.996542
# 5         0.092736            16.983847             56.513950  0.997104
# 6         0.084956            15.711599             40.869906  0.996615
# 7         0.076588            14.045226             35.020101  0.996104
# ...

# %%
df[(df['chlorides'] >= 0.08) & (df['citric acid'] <= 0.04)].head()
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1             7.8             0.880         0.00             2.6      0.098
# 2             7.8             0.760         0.04             2.3      0.092
# 12            5.6             0.615         0.00             1.6      0.089
# 28            7.1             0.710         0.00             1.9      0.080
# 29            7.8             0.645         0.00             2.0      0.082
#
#     free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1                  25.0                  67.0   0.9968  3.20       0.68
# 2                  15.0                  54.0   0.9970  3.26       0.65
# 12                 16.0                  59.0   0.9943  3.58       0.52
# 28                 14.0                  35.0   0.9972  3.47       0.55
# 29                  8.0                  16.0   0.9964  3.38       0.59
#
#     alcohol  quality
# 1       9.8        5
# 2       9.8        5
# ...

# %%
result_df = df.query('alcohol >= 9.10 and pH < 3.5')
result_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 6               7.9             0.600         0.06             1.6      0.069
# 7               7.3             0.650         0.00             1.2      0.065
# 8               7.8             0.580         0.02             2.0      0.073
# 9               7.5             0.500         0.36             6.1      0.071
# 10              6.7             0.580         0.08             1.8      0.097
# 11              7.5             0.500         0.36             6.1      0.071
# 13              7.8             0.610         0.29             1.6      0.114
# 14              8.9             0.620         0.18             3.8      0.176
# ...

# %%
result_df.loc[1:6]
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 6            7.9              0.60         0.06             1.6      0.069
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 6                 15.0                  59.0   0.9964  3.30       0.46
#
#    alcohol  quality
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 6      9.4        5

# %%
result_df.iloc[1:6]
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 6                 15.0                  59.0   0.9964  3.30       0.46
# 7                 15.0                  21.0   0.9946  3.39       0.47
# 8                  9.0                  18.0   0.9968  3.36       0.57
#
#    alcohol  quality
# 2      9.8        5
# 3      9.8        6
# 6      9.4        5
# ...

# %%
df.sort_values(by='fixed acidity', ascending = True).head()
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 45             4.6              0.52         0.15             2.1      0.054
# 95             4.7              0.60         0.17             2.3      0.058
# 821            4.9              0.42         0.00             2.1      0.048
# 588            5.0              0.42         0.24             2.0      0.060
# 94             5.0              1.02         0.04             1.4      0.045
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 45                   8.0                  65.0  0.99340  3.90       0.56
# 95                  17.0                 106.0  0.99320  3.85       0.60
# 821                 16.0                  42.0  0.99154  3.71       0.74
# 588                 19.0                  50.0  0.99170  3.72       0.74
# 94                  41.0                  85.0  0.99380  3.75       0.48
#
#      alcohol  quality
# 45      13.1        4
# ...

# %%
df.sort_values(by='fixed acidity', ascending = False).head()
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 652           15.9             0.360         0.65             7.5      0.096
# 557           15.6             0.645         0.49             4.2      0.095
# 442           15.6             0.685         0.76             3.7      0.100
# 555           15.5             0.645         0.49             4.2      0.095
# 554           15.5             0.645         0.49             4.2      0.095
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 652                 22.0                  71.0  0.99760  2.98       0.84
# 557                 10.0                  23.0  1.00315  2.92       0.74
# 442                  6.0                  43.0  1.00320  2.95       0.68
# 555                 10.0                  23.0  1.00315  2.92       0.74
# 554                 10.0                  23.0  1.00315  2.92       0.74
#
#      alcohol  quality
# 652     14.9        5
# ...

# %%
df.drop('pH', axis=1, inplace=True) # REMOVES pH

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density  sulphates  alcohol  \
# 0                 11.0                  34.0   0.9978       0.56      9.4
# 1                 25.0                  67.0   0.9968       0.68      9.8
# 2                 15.0                  54.0   0.9970       0.65      9.8
# 3                 17.0                  60.0   0.9980       0.58      9.8
# 4                 11.0                  34.0   0.9978       0.56      9.4
#
#    quality
# 0        5
# 1        5
# 2        5
# 3        6
# ...

# %%
df = df2

# %%
df2 = df.copy()

# %%
cols = df2.columns.tolist()

# %%
df2.columns = [col.lower().replace(' ', '_') for col in cols]

# %%
df2.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density  sulphates  alcohol  \
# 0                 11.0                  34.0   0.9978       0.56      9.4
# 1                 25.0                  67.0   0.9968       0.68      9.8
# 2                 15.0                  54.0   0.9970       0.65      9.8
# 3                 17.0                  60.0   0.9980       0.58      9.8
# 4                 11.0                  34.0   0.9978       0.56      9.4
#
#    quality
# 0        5
# 1        5
# 2        5
# 3        6
# ...

# %%
df2.eval('total_acidity = volatile_acidity + fixed_acidity', inplace = True)

# %%
df2.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density  sulphates  alcohol  \
# 0                 11.0                  34.0   0.9978       0.56      9.4
# 1                 25.0                  67.0   0.9968       0.68      9.8
# 2                 15.0                  54.0   0.9970       0.65      9.8
# 3                 17.0                  60.0   0.9980       0.58      9.8
# 4                 11.0                  34.0   0.9978       0.56      9.4
#
#    quality  total_acidity
# 0        5           8.10
# ...

# %%
list(map(lambda x: x**2, [2,3,4]))
# Out:
# [4, 9, 16]
